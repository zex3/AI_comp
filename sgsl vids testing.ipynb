# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\kohzi\anaconda3\lib\site-packages (4.7.0.68)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\kohzi\anaconda3\lib\site-packages (from opencv-python) (1.23.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\kohzi\anaconda3\lib\site-packages (2.11.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\kohzi\anaconda3\lib\site-packages (2.11.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.7.0)
# Requirement already satisfied: setuptools in c:\users\kohzi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (65.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.12.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.30.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.2)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (23.1.21)
# Requirement already satisfied: packaging in c:\users\kohzi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (22.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.51.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.23.5)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (15.0.6.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\kohzi\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.37.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.28.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.16.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\kohzi\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\kohzi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\kohzi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\kohzi\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\kohzi\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\kohzi\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.11.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kohzi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kohzi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\kohzi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kohzi\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2022.12.7)
# Requirement already satisfied: zipp>=0.5 in c:\users\kohzi\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\kohzi\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\kohzi\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install imutils
# Out:
# Requirement already satisfied: imutils in c:\users\kohzi\anaconda3\lib\site-packages (0.5.4)

# %%
from imutils import paths
from tqdm import tqdm
import pandas as pd 
import numpy as np
import shutil
import cv2
import os

# %%
# Open the .txt file which have names of training videos
f = open("sgsl_data/train/trainlist01.txt", "r")
temp = f.read()
videos = temp.split('\n')

# Create a dataframe having video names
train = pd.DataFrame()
train['video_name'] = videos
train = train[:-1]
train.head()
# Out:
#           video_name
# 0  Bedok-Bedok_1.MOV
# 1  Bedok-Bedok_2.mov
# 2  Bedok-Bedok_3.mov
# 3  Bedok-Bedok_4.MOV
# 4  Bedok-Bedok_5.mov

# %%
# Open the .txt file which have names of test videos
with open("sgsl_data/test/testlist01.txt", "r") as f:
    temp = f.read()
videos = temp.split("\n")

# Create a dataframe having video names
test = pd.DataFrame()
test["video_name"] = videos
test = test[:-1]
test.head()
# Out:
#               video_name
# 0      Bedok-Bedok_6.MOV
# 1      Bedok-Bedok_7.mov
# 2    Bishan-Bishan_6.MOV
# 3    Bishan-Bishan_7.mov
# 4  BoonLay-BoonLay_6.MOV

# %%
def extract_tag(video_path):
    return video_path.split("-")[0]

def separate_video_name(video_name):
    return video_name.split("-")[1]

def rectify_video_name(video_name):
    return video_name.split(" ")[0]

def move_videos(df, output_dir):
    if not os.path.exists(output_dir):
        os.mkdir(output_dir)
    for i in tqdm(range(df.shape[0])):
        videoFile = df['video_name'][i].split("-")[-1]
        videoPath = os.path.join("data", videoFile)
        shutil.copy2(videoPath, output_dir)
    print()
    print(f"Total videos: {len(os.listdir(output_dir))}")

# %%
train["tag"] = train["video_name"].apply(extract_tag)
train["video_name"] = train["video_name"].apply(separate_video_name)
train.head()
# Out:
#     video_name    tag
# 0  Bedok_1.MOV  Bedok
# 1  Bedok_2.mov  Bedok
# 2  Bedok_3.mov  Bedok
# 3  Bedok_4.MOV  Bedok
# 4  Bedok_5.mov  Bedok

# %%
train["video_name"] = train["video_name"].apply(rectify_video_name)
train.head()
# Out:
#     video_name    tag
# 0  Bedok_1.MOV  Bedok
# 1  Bedok_2.mov  Bedok
# 2  Bedok_3.mov  Bedok
# 3  Bedok_4.MOV  Bedok
# 4  Bedok_5.mov  Bedok

# %%
test["tag"] = test["video_name"].apply(extract_tag)
test["video_name"] = test["video_name"].apply(separate_video_name)
test.head()
# Out:
#       video_name      tag
# 0    Bedok_6.MOV    Bedok
# 1    Bedok_7.mov    Bedok
# 2   Bishan_6.MOV   Bishan
# 3   Bishan_7.mov   Bishan
# 4  BoonLay_6.MOV  BoonLay

# %%
train.to_csv("train.csv", index=False)
test.to_csv("test.csv", index=False)

# %%
# !pip install -q git+https://github.com/tensorflow/docs

# %%
from tensorflow_docs.vis import embed
from tensorflow import keras


import matplotlib.pyplot as plt
import tensorflow as tf
import imageio

# %%
IMG_SIZE = 224
BATCH_SIZE = 64
EPOCHS = 25

MAX_SEQ_LENGTH = 100
NUM_FEATURES = 2048

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

print(f"Total videos for training: {len(train_df)}")
print(f"Total videos for testing: {len(test_df)}")

train_df.sample(10)
# Out:
# Total videos for training: 96
# Total videos for testing: 37
#            video_name          tag
# 91      Orchard_5.mov      Orchard
# 81       Newton_5.mov       Newton
# 89      Orchard_3.mov      Orchard
# 5        Bishan_1.MOV       Bishan
# 57        Eunos_5.mov        Eunos
# 62      Kallang_5.mov      Kallang
# 61      Kallang_4.MOV      Kallang
# 37     CityHall_4.MOV     CityHall
# 28  BukitGombak_5.mov  BukitGombak
# 50   DhobyGhaut_3.mov   DhobyGhaut

# %%
# The following two methods are taken from this tutorial:
# https://www.tensorflow.org/hub/tutorials/action_recognition_with_tf_hub


def crop_center_square(frame):
    y, x = frame.shape[0:2]
    min_dim = min(y, x)
    start_x = (x // 2) - (min_dim // 2)
    start_y = (y // 2) - (min_dim // 2)
    return frame[start_y : start_y + min_dim, start_x : start_x + min_dim]


def load_video(path, max_frames=0, resize=(IMG_SIZE, IMG_SIZE)):
    cap = cv2.VideoCapture(path)
    frames = []
    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            frame = crop_center_square(frame)
            frame = cv2.resize(frame, resize)
            frame = frame[:, :, [2, 1, 0]]
            frames.append(frame)

            if len(frames) == max_frames:
                break
    finally:
        cap.release()
    return np.array(frames)

# %%
def build_feature_extractor():
    feature_extractor = keras.applications.InceptionV3(
        weights="imagenet",
        include_top=False,
        pooling="avg",
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
    )
    preprocess_input = keras.applications.inception_v3.preprocess_input

    inputs = keras.Input((IMG_SIZE, IMG_SIZE, 3))
    preprocessed = preprocess_input(inputs)

    outputs = feature_extractor(preprocessed)
    return keras.Model(inputs, outputs, name="feature_extractor")


feature_extractor = build_feature_extractor()

# %%
label_processor = keras.layers.StringLookup(
    num_oov_indices=0, vocabulary=np.unique(train_df["tag"])
)
print(label_processor.get_vocabulary())
# Out:
# ['Bedok', 'Bishan', 'BoonLay', 'Braddell', 'BukitBatok', 'BukitGombak', 'BuonaVista', 'CityHall', 'Clementi', 'Commonwealth', 'DhobyGhaut', 'Eunos', 'Kallang', 'Khatib', 'MarinaSouthPier', 'MoneyB', 'Newton', 'Novena', 'Orchard', 'OutramPark']

# %%
def prepare_all_videos(df, root_dir):
    num_samples = len(df)
    video_paths = df["video_name"].values.tolist()
    labels = df["tag"].values
    labels = label_processor(labels[..., None]).numpy()

    # `frame_masks` and `frame_features` are what we will feed to our sequence model.
    # `frame_masks` will contain a bunch of booleans denoting if a timestep is
    # masked with padding or not.
    frame_masks = np.zeros(shape=(num_samples, MAX_SEQ_LENGTH), dtype="bool")
    frame_features = np.zeros(
        shape=(num_samples, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32"
    )

    # For each video.
    for idx, path in enumerate(video_paths):
        # Gather all its frames and add a batch dimension.
        frames = load_video(os.path.join(root_dir, path))
        frames = frames[None, ...]

        # Initialize placeholders to store the masks and features of the current video.
        temp_frame_mask = np.zeros(shape=(1, MAX_SEQ_LENGTH,), dtype="bool")
        temp_frame_features = np.zeros(
            shape=(1, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32"
        )

        # Extract features from the frames of the current video.
        for i, batch in enumerate(frames):
            video_length = batch.shape[0]
            length = min(MAX_SEQ_LENGTH, video_length)
            for j in range(length):
                temp_frame_features[i, j, :] = feature_extractor.predict(
                    batch[None, j, :]
                )
            temp_frame_mask[i, :length] = 1  # 1 = not masked, 0 = masked

        frame_features[idx,] = temp_frame_features.squeeze()
        frame_masks[idx,] = temp_frame_mask.squeeze()

    return (frame_features, frame_masks), labels


train_data, train_labels = prepare_all_videos(train_df, "train")
test_data, test_labels = prepare_all_videos(test_df, "test")

print(f"Frame features in train set: {train_data[0].shape}")
print(f"Frame masks in train set: {train_data[1].shape}")
# Out:
# Frame features in train set: (96, 100, 2048)
# Frame masks in train set: (96, 100)

# %%
# Utility for our sequence model.
def get_sequence_model():
    class_vocab = label_processor.get_vocabulary()

    frame_features_input = keras.Input((MAX_SEQ_LENGTH, NUM_FEATURES))
    mask_input = keras.Input((MAX_SEQ_LENGTH,), dtype="bool")

    # Refer to the following tutorial to understand the significance of using `mask`:
    # https://keras.io/api/layers/recurrent_layers/gru/
    x = keras.layers.GRU(16, return_sequences=True)(
        frame_features_input, mask=mask_input
    )
    x = keras.layers.GRU(8)(x)
    x = keras.layers.Dropout(0.4)(x)
    x = keras.layers.Dense(8, activation="relu")(x)
    output = keras.layers.Dense(len(class_vocab), activation="softmax")(x)

    rnn_model = keras.Model([frame_features_input, mask_input], output)

    rnn_model.compile(
        loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"]
    )
    return rnn_model


# Utility for running experiments.
def run_experiment():
    filepath = "./video_classifier"
    checkpoint = keras.callbacks.ModelCheckpoint(
        filepath, save_weights_only=True, save_best_only=True, verbose=1
    )

    seq_model = get_sequence_model()
    history = seq_model.fit(
        [train_data[0], train_data[1]],
        train_labels,
        validation_split=0.3,
        epochs=EPOCHS,
        callbacks=[checkpoint],
    )

    seq_model.load_weights(filepath)
    _, accuracy = seq_model.evaluate([test_data[0], test_data[1]], test_labels)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")

    return history, seq_model


_, sequence_model = run_experiment()
# Out:
# Epoch 1/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9957 - accuracy: 0.0299
# Epoch 1: val_loss improved from inf to 2.99854, saving model to .\video_classifier
# 3/3 [==============================] - 15s 2s/step - loss: 2.9957 - accuracy: 0.0299 - val_loss: 2.9985 - val_accuracy: 0.0000e+00
# Epoch 2/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9944 - accuracy: 0.0746
# Epoch 2: val_loss did not improve from 2.99854
# 3/3 [==============================] - 1s 211ms/step - loss: 2.9944 - accuracy: 0.0746 - val_loss: 3.0010 - val_accuracy: 0.0000e+00
# Epoch 3/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9932 - accuracy: 0.0746
# Epoch 3: val_loss did not improve from 2.99854
# 3/3 [==============================] - 1s 241ms/step - loss: 2.9932 - accuracy: 0.0746 - val_loss: 3.0035 - val_accuracy: 0.0000e+00
# Epoch 4/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9922 - accuracy: 0.0746
# Epoch 4: val_loss did not improve from 2.99854
# 3/3 [==============================] - 1s 246ms/step - loss: 2.9922 - accuracy: 0.0746 - val_loss: 3.0060 - val_accuracy: 0.0000e+00
# Epoch 5/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9911 - accuracy: 0.0746
# Epoch 5: val_loss did not improve from 2.99854
# 3/3 [==============================] - 1s 201ms/step - loss: 2.9911 - accuracy: 0.0746 - val_loss: 3.0085 - val_accuracy: 0.0000e+00
# Epoch 6/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9901 - accuracy: 0.0746
# Epoch 6: val_loss did not improve from 2.99854
# 3/3 [==============================] - 1s 201ms/step - loss: 2.9901 - accuracy: 0.0746 - val_loss: 3.0111 - val_accuracy: 0.0000e+00
# Epoch 7/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9890 - accuracy: 0.0746
# Epoch 7: val_loss did not improve from 2.99854
# 3/3 [==============================] - 1s 227ms/step - loss: 2.9890 - accuracy: 0.0746 - val_loss: 3.0136 - val_accuracy: 0.0000e+00
# Epoch 8/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9879 - accuracy: 0.0746
# Epoch 8: val_loss did not improve from 2.99854
# 3/3 [==============================] - 1s 190ms/step - loss: 2.9879 - accuracy: 0.0746 - val_loss: 3.0162 - val_accuracy: 0.0000e+00
# Epoch 9/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9868 - accuracy: 0.0746
# Epoch 9: val_loss did not improve from 2.99854
# 3/3 [==============================] - 1s 190ms/step - loss: 2.9868 - accuracy: 0.0746 - val_loss: 3.0188 - val_accuracy: 0.0000e+00
# Epoch 10/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9857 - accuracy: 0.0746
# Epoch 10: val_loss did not improve from 2.99854
# 3/3 [==============================] - 1s 190ms/step - loss: 2.9857 - accuracy: 0.0746 - val_loss: 3.0214 - val_accuracy: 0.0000e+00
# Epoch 11/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9846 - accuracy: 0.0746
# Epoch 11: val_loss did not improve from 2.99854
# 3/3 [==============================] - 1s 190ms/step - loss: 2.9846 - accuracy: 0.0746 - val_loss: 3.0239 - val_accuracy: 0.0000e+00
# Epoch 12/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9836 - accuracy: 0.0746
# Epoch 12: val_loss did not improve from 2.99854
# 3/3 [==============================] - 1s 304ms/step - loss: 2.9836 - accuracy: 0.0746 - val_loss: 3.0265 - val_accuracy: 0.0000e+00
# Epoch 13/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9825 - accuracy: 0.0746
# Epoch 13: val_loss did not improve from 2.99854
# 3/3 [==============================] - 1s 233ms/step - loss: 2.9825 - accuracy: 0.0746 - val_loss: 3.0291 - val_accuracy: 0.0000e+00
# Epoch 14/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9815 - accuracy: 0.0746
# Epoch 14: val_loss did not improve from 2.99854
# 3/3 [==============================] - 1s 200ms/step - loss: 2.9815 - accuracy: 0.0746 - val_loss: 3.0316 - val_accuracy: 0.0000e+00
# Epoch 15/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9805 - accuracy: 0.0597
# Epoch 15: val_loss did not improve from 2.99854
# 3/3 [==============================] - 1s 263ms/step - loss: 2.9805 - accuracy: 0.0597 - val_loss: 3.0342 - val_accuracy: 0.0000e+00
# Epoch 16/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9794 - accuracy: 0.0597
# Epoch 16: val_loss did not improve from 2.99854
# 3/3 [==============================] - 1s 299ms/step - loss: 2.9794 - accuracy: 0.0597 - val_loss: 3.0368 - val_accuracy: 0.0000e+00
# Epoch 17/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9783 - accuracy: 0.0746
# Epoch 17: val_loss did not improve from 2.99854
# 3/3 [==============================] - 1s 209ms/step - loss: 2.9783 - accuracy: 0.0746 - val_loss: 3.0394 - val_accuracy: 0.0000e+00
# Epoch 18/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9773 - accuracy: 0.0746
# Epoch 18: val_loss did not improve from 2.99854
# 3/3 [==============================] - 1s 205ms/step - loss: 2.9773 - accuracy: 0.0746 - val_loss: 3.0421 - val_accuracy: 0.0000e+00
# Epoch 19/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9762 - accuracy: 0.0746
# Epoch 19: val_loss did not improve from 2.99854
# 3/3 [==============================] - 1s 191ms/step - loss: 2.9762 - accuracy: 0.0746 - val_loss: 3.0447 - val_accuracy: 0.0000e+00
# Epoch 20/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9751 - accuracy: 0.0746
# Epoch 20: val_loss did not improve from 2.99854
# 3/3 [==============================] - 1s 192ms/step - loss: 2.9751 - accuracy: 0.0746 - val_loss: 3.0473 - val_accuracy: 0.0000e+00
# Epoch 21/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9740 - accuracy: 0.0746
# Epoch 21: val_loss did not improve from 2.99854
# 3/3 [==============================] - 1s 209ms/step - loss: 2.9740 - accuracy: 0.0746 - val_loss: 3.0500 - val_accuracy: 0.0000e+00
# Epoch 22/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9730 - accuracy: 0.0746
# Epoch 22: val_loss did not improve from 2.99854
# 3/3 [==============================] - 1s 186ms/step - loss: 2.9730 - accuracy: 0.0746 - val_loss: 3.0526 - val_accuracy: 0.0000e+00
# Epoch 23/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9720 - accuracy: 0.0746
# Epoch 23: val_loss did not improve from 2.99854
# 3/3 [==============================] - 0s 174ms/step - loss: 2.9720 - accuracy: 0.0746 - val_loss: 3.0552 - val_accuracy: 0.0000e+00
# Epoch 24/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9709 - accuracy: 0.0746
# Epoch 24: val_loss did not improve from 2.99854
# 3/3 [==============================] - 1s 205ms/step - loss: 2.9709 - accuracy: 0.0746 - val_loss: 3.0578 - val_accuracy: 0.0000e+00
# Epoch 25/25
# 3/3 [==============================] - ETA: 0s - loss: 2.9699 - accuracy: 0.0746
# Epoch 25: val_loss did not improve from 2.99854
# 3/3 [==============================] - 1s 193ms/step - loss: 2.9699 - accuracy: 0.0746 - val_loss: 3.0604 - val_accuracy: 0.0000e+00
# 2/2 [==============================] - 0s 40ms/step - loss: 2.9958 - accuracy: 0.0270
# Test accuracy: 2.7%

# %%
def prepare_single_video(frames):
    frames = frames[None, ...]
    frame_mask = np.zeros(shape=(1, MAX_SEQ_LENGTH,), dtype="bool")
    frame_features = np.zeros(shape=(1, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32")

    for i, batch in enumerate(frames):
        video_length = batch.shape[0]
        length = min(MAX_SEQ_LENGTH, video_length)
        for j in range(length):
            frame_features[i, j, :] = feature_extractor.predict(batch[None, j, :])
        frame_mask[i, :length] = 1  # 1 = not masked, 0 = masked

    return frame_features, frame_mask


def sequence_prediction(path):
    class_vocab = label_processor.get_vocabulary()

    frames = load_video(os.path.join("test", path))
    frame_features, frame_mask = prepare_single_video(frames)
    probabilities = sequence_model.predict([frame_features, frame_mask])[0]

    for i in np.argsort(probabilities)[::-1]:
        print(f"  {class_vocab[i]}: {probabilities[i] * 100:5.2f}%")
    return frames


# This utility is for visualization.
# Referenced from:
# https://www.tensorflow.org/hub/tutorials/action_recognition_with_tf_hub
def to_gif(images):
    converted_images = images.astype(np.uint8)
    imageio.mimsave("animation.gif", converted_images, fps=10)
    return embed.embed_file("animation.gif")


test_video = np.random.choice(test_df["video_name"].values.tolist())
print(f"Test video path: {test_video}")
test_frames = sequence_prediction(test_video)
# to_gif(test_frames[:MAX_SEQ_LENGTH])
# Out:
# Test video path: BukitBatok_6.MOV
# 1/1 [==============================] - 3s 3s/step
#   Eunos:  5.01%
#   CityHall:  5.01%
#   Bishan:  5.01%
#   BoonLay:  5.01%
#   BukitBatok:  5.01%
#   Khatib:  5.01%
#   Commonwealth:  5.01%
#   BuonaVista:  5.01%
#   Kallang:  5.01%
#   Braddell:  5.00%
#   Clementi:  5.00%
#   BukitGombak:  5.00%
#   Bedok:  5.00%
#   DhobyGhaut:  5.00%
#   Orchard:  4.99%
#   MarinaSouthPier:  4.99%
#   MoneyB:  4.99%
#   Newton:  4.99%
#   Novena:  4.99%
#   OutramPark:  4.99%
